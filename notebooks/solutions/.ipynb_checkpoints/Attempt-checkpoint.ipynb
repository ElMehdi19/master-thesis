# %%
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp
from matplotlib import pyplot as plt
from PIL import Image

# %%
Image.open('discretized.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=546x50 at 0x7F4CD13D35B0>

# %%
def rhs(w, t, N, M, m, Bn, dpdz):
    dwdt = np.zeros(N)
    w[0], w[-1] = 0, -1
    dr = 1 / N
    
    for i in range(1, N-1):
        wr = (w[i+1] - w[i-1]) / (2 * dr)
        wrr = (w[i+1] - 2 * w[i] + w[i-1]) / (dr ** 2)
        r = i * dr
        A = 0.5 * (wrr + wr / r)
        B = (M**2) * (w[i] + 1) / (1 + m**2)
        C = Bn / r
        dwdt[i] = A - B + C - dpdz
        dwdt[i] *= 0.5
    return dwdt
N = 30

# %%
def solver_1(t, w):
    M2 = 20
    m = 1.5
    Bn = 10
    dpdz = 30
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s1 = solve_ivp(solver_1, (0, 1), w0)
df1 = pd.DataFrame(s1.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(2, N, 3):
#     plt.plot(np.arange(N), df1.iloc[:, 30], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df1.iloc[:, 30])

# %%
def solver_2(t, w):
    M2 = 20
    m = 1.5
    Bn = 10
    dpdz = 60
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s2 = solve_ivp(solver_2, (0, 1), w0)
df2 = pd.DataFrame(s2.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df2.iloc[:, 30])

# %%
def solver_3(t, w):
    M2 = 20
    m = 1.5
    Bn = 10
    dpdz = 120
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s3 = solve_ivp(solver_3, (0, 1), w0)
df3 = pd.DataFrame(s3.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df3.iloc[:, 30])

# %%
r = np.array([x / N for x in np.arange(N)])
plt.plot(r, df1.iloc[:, 30], linewidth=2, label=r'$\frac{dp}{dz}=30$')
plt.plot(r, df2.iloc[:, 30], linewidth=2, label=r'$\frac{dp}{dz}=60$')
plt.plot(r, df3.iloc[:, 30], linewidth=2, label=r'$\frac{dp}{dz}=120$', color='green')
plt.xlabel('$r_{i}$')
plt.ylabel('$w$')
plt.legend()
title = r"""Représentation graphique de la vitesse axiale $w(r)$
à $t=30$, $M=100$, $m=1.5$, $\beta=2$ et $B_{n}=10$
"""
plt.tight_layout()
plt.title(title, fontsize=10, y=-0.4)
plt.savefig('figs/case1.png', transparent=True)

# %%
def solver_4(t, w):
    M2 = 250**0.5
    m = 1.5
    Bn = 10
    dpdz = 10
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s4 = solve_ivp(solver_4, (0, 1), w0)
df4 = pd.DataFrame(s4.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df4.iloc[:, 30])

# %%
def solver_5(t, w):
    M2 = 500**0.5
    m = 1.5
    Bn = 10
    dpdz = 10
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s5 = solve_ivp(solver_5, (0, 1), w0)
df5 = pd.DataFrame(s5.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df5.iloc[:, 30])

# %%
def solver_6(t, w):
    M2 = 1000**0.5
    m = 1.5
    Bn = 10
    dpdz = 10
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s6 = solve_ivp(solver_6, (0, 1), w0)
df6 = pd.DataFrame(s6.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df6.iloc[:, 30])

# %%
r = np.array([x / N for x in np.arange(N)])
plt.plot(r, df4.iloc[:, 30], linewidth=2, label=r'$M=100$')
plt.plot(r, df5.iloc[:, 30], linewidth=2, label=r'$M=500$')
plt.plot(r, df6.iloc[:, 30], linewidth=2, label=r'$M=1000$', color='green')
plt.xlabel('$r_{i}$')
plt.ylabel('$w$')
plt.legend()
title = r"""Représentation graphique de la vitesse axiale $w(r)$
à $t=30$, $dpdz=10$, $m=1.5$, $\beta=2$ et $B_{n}=10$
"""
plt.tight_layout()
plt.title(title, fontsize=10, y=-0.4)
plt.savefig('figs/case2.png', transparent=True)

# %%
def solver_7(t, w):
    M2 = 1000**0.5
    m = 1.5
    Bn = 10
    dpdz = 10
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s7 = solve_ivp(solver_7, (0, 1), w0)
df7 = pd.DataFrame(s7.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df7.iloc[:, 30])

# %%
def solver_8(t, w):
    M2 = 1000**0.5
    m = 1.5
    Bn = 0
    dpdz = 10
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s8 = solve_ivp(solver_8, (0, 1), w0)
df8 = pd.DataFrame(s8.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df8.iloc[:, 30])

# %%
def solver_9(t, w):
    M2 = 1000**0.5
    m = 1.5
    Bn = 15
    dpdz = 10
    return rhs(w, t, N, M2, m, Bn, dpdz)

w0 = np.ones(N)

s9 = solve_ivp(solver_9, (0, 1), w0)
df9 = pd.DataFrame(s9.y)

# %%
plt.style.use('fivethirtyeight')
# for i in range(0, N, 10):
#     plt.plot(np.arange(N), df.iloc[:, i], label=f'$t={i}$', linewidth=2)
plt.plot(np.arange(N), df9.iloc[:, 30])

# %%
r = np.array([x / N for x in np.arange(N)])
plt.plot(r, df8.iloc[:, 30], linewidth=2, label=r'$B_{n}=0$')
plt.plot(r, df7.iloc[:, 30], linewidth=2, label=r'$B_{n}=10$')
plt.plot(r, df9.iloc[:, 30], linewidth=2, label=r'$B_{n}=15$', color='green')
plt.xlabel('$r_{i}$')
plt.ylabel('$w$')
plt.legend()
title = r"""Représentation graphique de la vitesse axiale $w(r)$
à $t=30$, $dpdz=10$, $m=1.5$, $\beta=2$ et $M=1000$
"""
plt.tight_layout()
plt.title(title, fontsize=10, y=-0.4)
plt.savefig('figs/case3.png', transparent=True)
