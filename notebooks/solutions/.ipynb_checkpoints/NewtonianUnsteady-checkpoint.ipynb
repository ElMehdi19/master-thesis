# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.integrate import solve_ivp, odeint

# %%
def results_path(name):
    import os
    base = './results/newtonian'
    return os.path.abspath(os.path.join(base, name))

# %%
M, m = 10, 1.5
_z, _t = 0.5, 1
eps, omega, beta = 0.2, 50, 10
# eps, omega, beta = 0.2, 10, pow(10, -5)
q1, q2 = 0.2, 0.4
pi = np.math.pi

# %%
def A2(M=M, m=m):
    return 2 * pow(M, 2) / (1 + pow(m, 2))

def A(M=M, m=m):
    return np.sqrt(A2(M=M, m=m))

# %%
r1 = 0.5

@np.vectorize
def r2(z=_z, eps=eps):
    return 1 + eps * np.math.cos(2 * pi * z)

with plt.style.context('fivethirtyeight'):
    plt.plot(np.linspace(0, 1, 80), r2(z=np.linspace(0, 1, 80)))
    plt.ylim(bottom=0.5)
    fig = plt.gcf()
    fig.set_size_inches(7.5, 2.5)
    sp = r'\hspace{0.4}'
    t = fr'$Représenation{sp}de{sp}r_{2}(z)$'
    fig.suptitle(t, fontsize=16)
    plt.xlabel('z')
    plt.ylabel('$r_{2}$', fontsize=17)
    plt.tight_layout()
#     plt.savefig('figs/outer-radius.png', transparent=True)

# %%
@np.vectorize
def q(t=_t, omega=omega, q1=q1, q2=q2):
    return q1 + q2 * np.math.sin(omega * t)

@np.vectorize
def dqdt(t=_t, omega=omega, q2=q2):
    return omega * q2 * np.math.cos(omega * t)

@np.vectorize
def dpdz(wr2, wr1, z=_z, t=_t, beta=beta, eps=eps, omega=omega, q1=q1, q2=q2, M=M, m=m):
    r2_r1 = np.math.pow(r2(z=z, eps=eps), 2) - np.math.pow(r1, 2)
    
    part_1 = beta * dqdt(t=t, omega=omega, q2=q2) / (pi * r2_r1)
    part_2 = (r2_r1 / 2) + q(t=t, omega=omega, q1=q1, q2=q2) / (2 * pi)
    part_2 *= A2(M=M, m=m) / r2_r1
    part_3 = (r2(z) * wr2 - r1 * wr1) / r2_r1
    return -(part_1 + part_2 - part_3)

# %%
from PIL import Image

# %%
Image.open('newtonian-semi-discretization.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=654x169 at 0x7F6228671A60>

# %%
Image.open('newtonian-discretization-full.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=631x127 at 0x7F61E5AF8F40>

# %%
_N = 50
def rhs(w, t, N=_N, z=_z, M=M, m=m, beta=beta, eps=eps, omega=omega):
    dwdt = np.zeros(N)
    w[0], w[-1] = -1, -1
    dr = (r2(z, eps) - r1) / N
    nr = N -1
    
    # first derivatives of w
    wr1 = (-3 * w[0] + 4 * w[1] - w[2]) / (2 * dr)
    wr2 = (3 * w[nr] - 4 * w[nr - 1] + w[nr - 2]) / (2 * dr)
    
    # main loop
    for i in range(1, N-1):
#         wr1 = (-3 * w[0] + 4 * w[1] - w[2]) / (2 * dr)
#         wr2 = (3 * w[nr] - 4 * w[nr - 1] + w[nr - 2]) / (2 * dr)
        wr = (w[i+1] - w[i-1]) / (2 * dr)
        wrr = (w[i+1] - 2 * w[i] + w[i-1]) / (dr ** 2)
        r = i * dr + 0.5
        part_1 = 0.5 * (wrr + wr / r)
        part_2 = A2(M=M, m=m) * (w[i] + 1) / 2
        part_3 = dpdz(wr2, wr1, z=z, t=t, eps=eps, omega=omega, beta=beta)
        dwdt[i] = part_1 - part_2 - part_3
        dwdt[i] /= beta
    return dwdt

# %%
def solver_default(t, w):
    return rhs(w, t, omega=10)

w0 = np.ones(_N)
w0 *= -1

s_default = solve_ivp(solver_default, (0, 1), w0)
# t_default = np.linspace(0, 1, 30)
# s_default = odeint(rhs, w0, t_default)
df_default = pd.DataFrame(s_default.y)
# df_default.to_csv(results_path('small_beta_numerical_axial_velocity.csv'))
df_default.head(2)
# Out:
#    0         1         2         3         4         5         6         7     \
# 0  -1.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  -1.0 -0.997395 -0.994163 -0.992279 -0.990887 -0.989556 -0.988349 -0.987262
#
#        8         9     ...      1667      1668      1669      1670      1671  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.986178 -0.985079  ... -0.882815 -0.882996 -0.883174 -0.883375 -0.883591
#
#        1672      1673      1674      1675      1676
# 0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.883763 -0.883933 -0.884126 -0.884313 -0.884497
#
# [2 rows x 1677 columns]

# %%
df_default.to_csv(results_path('small_beta_numerical_axial_velocity.csv'))

# %%
def get_t(t):
    return f'{s_default.t[t]:.3f}'
with plt.style.context('fivethirtyeight'):
    r_s = np.linspace(0.5, 0.8, 50)
#     plt.plot(r_s, df_default.iloc[:, 0], linewidth=1, label=f't={get_t(0)}')
#     plt.plot(r_s, df_default.iloc[:, 100], linewidth=1, label=f't={get_t(100)}')
#     plt.plot(r_s, df_default.iloc[:, 120], linewidth=1, label=f't={get_t(120)}')
#     plt.plot(r_s, df_default.iloc[:, 140], linewidth=1, label=f't={get_t(140)}')
    plt.plot(r_s, df_default.iloc[:, 230], linewidth=1, label=f't={get_t(230)}', color='black')
    
    plt.legend()
    fig = plt.gcf()
    fig.set_size_inches(12.5, 5.5)
    sp = r'\hspace{0.2}'
    t = fr'$Evolution{sp}de{sp}w{sp}dans{sp}le{sp}temps{sp}pour{sp}z=0.5,{sp}\epsilon=0.2,{sp}M=10,{sp}m=1.5,{sp}\beta=10{sp}et{sp}\omega=50$'
    fig.suptitle(t, fontsize=16)
#     plt.savefig('figs/newtonian-unsteady-time-evolution.png', transparent=True)

# %%
def get_t(t):
    return f'{s_default.t[t]:.4f}'

with plt.style.context('fivethirtyeight'):
    r_s = np.linspace(0.5, 0.8, 50)
    sp = r'\hspace{0.2}'
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
    fig.set_size_inches(12.5, 5.5)
    fig.suptitle(fr'$Evolution{sp}de{sp}w{sp}dans{sp}le{sp}temps{sp}pour{sp}z=0.5,{sp}\epsilon=0.2,{sp}M=10,{sp}m=1.5,{sp}\beta=10{sp}et{sp}\omega=50$', fontsize=16)
    
    # ax1
    ax1.plot(r_s, df_default.iloc[:, 0], linewidth=1, label=f't={get_t(0)}')
    ax1.plot(r_s, df_default.iloc[:, 10], linewidth=1, label=f't={get_t(10)}', color='crimson')
    ax1.plot(r_s, df_default.iloc[:, 40], linewidth=1, label=f't={get_t(20)}', color='black')
    ax1.plot(r_s, df_default.iloc[:, 50], linewidth=1, label=f't={get_t(50)}', color='orange')
    ax1.legend()
    
    ax2.plot(r_s, df_default.iloc[:, 80 * 2], linewidth=1, label=f't={get_t(80)}')
    ax2.plot(r_s, df_default.iloc[:, 100 * 2], linewidth=1, label=f't={get_t(200)}', color='crimson')
    ax2.plot(r_s, df_default.iloc[:, 120 * 2], linewidth=1, label=f't={get_t(240)}', color='black')
    ax2.plot(r_s, df_default.iloc[:, 150 * 2], linewidth=1, label=f't={get_t(300)}', color='orange')
    ax2.legend()
    
    ax3.plot(r_s, df_default.iloc[:, 120 * 3], linewidth=1, label=f't={get_t(120 * 3)}')
    ax3.plot(r_s, df_default.iloc[:, 140 * 3], linewidth=1, label=f't={get_t(140 * 3)}', color='crimson')
    ax3.plot(r_s, df_default.iloc[:, 160 * 3], linewidth=1, label=f't={get_t(160 * 3)}', color='black')
    ax3.plot(r_s, df_default.iloc[:, 180 * 3], linewidth=1, label=f't={get_t(180 * 3)}', color='orange')
    ax3.legend()
    
    ax4.plot(r_s, df_default.iloc[:, 200 * 3], linewidth=1, label=f't={get_t(200 * 3)}')
    ax4.plot(r_s, df_default.iloc[:, 220 * 3], linewidth=1, label=f't={get_t(200 * 3)}', color='crimson')
#     ax4.plot(r_s, df_default.iloc[:, 240 * 3], linewidth=1, label=f't={get_t(240 * 3)}', color='black')
#     ax4.plot(r_s, df_default.iloc[:, 260 * 3], linewidth=1, label=f't={get_t(260 * 3)}', color='orange')
    ax4.legend()
#     plt.savefig('figs/newtonian-unsteady-4-t-evolution.png', transparent=True)

# %%
def solver_hartmann_1(t, w):
    return rhs(w, t, M=1)

s_hartmann_1 = solve_ivp(solver_hartmann_1, (0, 1), w0)

# %%
df_hartmann_1 = pd.DataFrame(s_hartmann_1.y)
df_hartmann_1.head(2)
# Out:
#    0        1        2         3         4         5         6         7     \
# 0  -1.0 -1.00000 -1.00000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  -1.0 -0.98954 -0.98294 -0.978015 -0.973549 -0.969707 -0.966189 -0.962901
#
#        8        9     ...     1665      1666      1667      1668      1669  \
# 0 -1.000000 -1.00000  ... -1.00000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.959828 -0.95694  ... -0.56847 -0.566007 -0.563761 -0.561691 -0.559552
#
#        1670      1671      1672      1673      1674
# 0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.557191 -0.554689 -0.552336 -0.550274 -0.548716
#
# [2 rows x 1675 columns]

# %%
def solver_hartmann_20(t, w):
    return rhs(w, t, M=20)

s_hartmann_20 = solve_ivp(solver_hartmann_20, (0, 1), w0)

# %%
df_hartmann_20 = pd.DataFrame(s_hartmann_20.y)
df_hartmann_20.head(2)
# Out:
#    0         1         2         3         4         5         6         7     \
# 0  -1.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  -1.0 -0.989636 -0.983109 -0.978291 -0.973966 -0.970267 -0.966907 -0.963798
#
#        8         9     ...      1670      1671      1672      1673      1674  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.960915 -0.958221  ... -0.947814 -0.945697 -0.943842 -0.942058 -0.940112
#
#       1675      1676      1677      1678      1679
# 0 -1.00000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.93795 -0.935782 -0.933883 -0.932188 -0.930686
#
# [2 rows x 1680 columns]

# %%
def solver_hartmann_50(t, w):
    return rhs(w, t, M=50)

s_hartmann_50 = solve_ivp(solver_hartmann_50, (0, 1), w0)

# %%
df_hartmann_50 = pd.DataFrame(s_hartmann_50.y)
df_hartmann_50.head(2)
# Out:
#    0         1        2         3         4         5         6         7     \
# 0  -1.0 -1.000000 -1.00000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  -1.0 -0.990105 -0.98396 -0.979647 -0.975994 -0.972963 -0.970321 -0.967997
#
#        8         9     ...      1690      1691      1692     1693      1694  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.00000 -1.000000
# 1 -0.965924 -0.964041  ... -0.959966 -0.958925 -0.957897 -0.95676 -0.955552
#
#        1695      1696      1697      1698     1699
# 0 -1.000000 -1.000000 -1.000000 -1.000000 -1.00000
# 1 -0.954605 -0.953676 -0.952657 -0.951585 -0.95141
#
# [2 rows x 1700 columns]

# %%
def solver_hartmann_0(t, w):
    return rhs(w, t, M=0)

s_hartmann_0 = solve_ivp(solver_hartmann_0, (0, 1), w0)

# %%
df_hartmann_0 = pd.DataFrame(s_hartmann_0.y)
df_hartmann_0.head(2)
# Out:
#    0        1        2         3         4         5         6         7     \
# 0  -1.0 -1.00000 -1.00000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  -1.0 -0.98954 -0.98294 -0.978014 -0.973548 -0.969706 -0.966187 -0.962899
#
#        8         9     ...      1666      1667      1668      1669      1670  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.959825 -0.956937  ... -0.560449 -0.558233 -0.555925 -0.553552 -0.551229
#
#        1671      1672      1673      1674      1675
# 0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.549023 -0.546863 -0.544633 -0.542307 -0.542157
#
# [2 rows x 1676 columns]

# %%
def solver_hartmann_5(t, w):
    return rhs(w, t, M=5)

s_hartmann_5 = solve_ivp(solver_hartmann_5, (0, 1), w0)

# %%
df_hartmann_5 = pd.DataFrame(s_hartmann_5.y)
df_hartmann_5.head(2)
# Out:
#    0         1        2         3         4         5         6         7     \
# 0  -1.0 -1.000000 -1.00000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  -1.0 -0.989546 -0.98295 -0.978032 -0.973575 -0.969741 -0.966233 -0.962956
#
#        8         9     ...      1666      1667      1668      1669      1670  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.959895 -0.957019  ... -0.688655 -0.686775 -0.684883 -0.682814 -0.680753
#
#        1671      1672      1673     1674      1675
# 0 -1.000000 -1.000000 -1.000000 -1.00000 -1.000000
# 1 -0.678485 -0.675857 -0.673799 -0.67175 -0.671156
#
# [2 rows x 1676 columns]

# %%
with plt.style.context('fivethirtyeight'):
    r_s = np.linspace(0.5, 0.8, 50)
    sp = r'\hspace{0.2}'
    fig = plt.gcf()
    fig.set_size_inches(12.5, 5.5)
    fig.suptitle(fr'$Représentation{sp}de{sp}w{sp}pour{sp}{sp}t=0.5,{sp}z=0.5,{sp}\epsilon=0.2,{sp}m=1.5,{sp}\beta=10{sp}et{sp}\omega=50$', fontsize=16)
    
    # ax1
    plt.plot(r_s, df_hartmann_0.iloc[:, 837], linewidth=1, label='M=0', linestyle='None', marker='.')
    plt.plot(r_s, df_hartmann_1.iloc[:, 837], linewidth=1, label='M=1')
    plt.plot(r_s, df_hartmann_5.iloc[:, 837], linewidth=1, label='M=5')
    plt.plot(r_s, df_default.iloc[:, 839], linewidth=1, label='M=10')
    plt.plot(r_s, df_hartmann_20.iloc[:, 839], linewidth=1, label='M=20', color='black')
#     plt.plot(r_s, df_hartmann_50.iloc[:, 850], linewidth=1, label='M=50', color='black')
  
    plt.xlabel('r', fontsize=22)
    plt.ylabel('w', fontsize=22)
    plt.legend(framealpha=0.1)
    plt.tight_layout()
    
    plt.savefig('figs/newtonian-unsteady-hartmann-t0.5-latest.png', transparent=True)

# %%
with plt.style.context('fivethirtyeight'):
    r_s = np.linspace(0.5, 0.8, 50)
    sp = r'\hspace{0.2}'
    fig = plt.gcf()
    fig.set_size_inches(12.5, 5.5)
    fig.suptitle(fr'$Représentation{sp}de{sp}w{sp}pour{sp}{sp}t=1,{sp}z=0.5,{sp}\epsilon=0.2,{sp}m=1.5,{sp}\beta=10{sp}et{sp}\omega=50$', fontsize=16)
    
    # ax1
    plt.plot(r_s, df_hartmann_0.iloc[:, 1675], linewidth=1, label='M=0', color='crimson')
    plt.plot(r_s, df_hartmann_1.iloc[:, 1674], linewidth=1, label='M=1')
    plt.plot(r_s, df_hartmann_5.iloc[:, 1675], linewidth=1, label='M=5')
    plt.plot(r_s, df_default.iloc[:, 1676], linewidth=1, label='M=10')
#     plt.plot(r_s, df_hartmann_20.iloc[:, 1679], linewidth=1, label='M=20')
#     plt.plot(r_s, df_hartmann_50.iloc[:, 1699], linewidth=1, label='M=50', color='black')

    plt.xlabel('r', fontsize=22)
    plt.ylabel('w', fontsize=22)
    plt.legend(framealpha=0.1)
    plt.tight_layout()
    
    plt.savefig('figs/newtonian-unsteady-hartmann-t1-latest.png', transparent=True)

# %%
def solver_occlusion_1(t, w):
    return rhs(w, t, eps=0.1)

s_occlusion_1 = solve_ivp(solver_occlusion_1, (0, 1), w0)

# %%
df_occlusion_1 = pd.DataFrame(s_occlusion_1.y)
df_occlusion_1.head(2)
# Out:
#    0         1         2         3         4         5         6         7    \
# 0 -1.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -1.0 -0.986943 -0.978089 -0.971399 -0.965827 -0.961014 -0.956814 -0.952755
#
#         8         9    ...       934       935       936       937       938  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.948972 -0.945722  ... -0.869249 -0.865227 -0.862545 -0.859854 -0.856495
#
#        939       940       941       942       943
# 0 -1.00000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.85287 -0.849837 -0.846827 -0.843355 -0.842442
#
# [2 rows x 944 columns]

# %%
def solver_occlusion_15(t, w):
    return rhs(w, t, eps=0.15)

s_occlusion_15 = solve_ivp(solver_occlusion_15, (0, 1), w0)

# %%
df_occlusion_15 = pd.DataFrame(s_occlusion_15.y)
df_occlusion_15.head(2)
# Out:
#    0        1         2         3         4        5         6         7     \
# 0  -1.0 -1.00000 -1.000000 -1.000000 -1.000000 -1.00000 -1.000000 -1.000000
# 1  -1.0 -0.98784 -0.980432 -0.974712 -0.969763 -0.96554 -0.961509 -0.957761
#
#        8         9     ...      1222      1223      1224      1225     1226  \
# 0 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000 -1.000000 -1.00000
# 1 -0.954438 -0.951419  ... -0.864442 -0.861718 -0.858496 -0.856294 -0.85409
#
#        1227      1228      1229      1230      1231
# 0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1 -0.851569 -0.848207 -0.845863 -0.843533 -0.841146
#
# [2 rows x 1232 columns]

# %%
with plt.style.context('fivethirtyeight'):
    r_s = np.linspace(0.5, 0.8, 50)
    sp = r'\hspace{0.2}'
    fig = plt.gcf()
    fig.set_size_inches(12.5, 5.5)
    fig.suptitle(fr'$Représentation{sp}de{sp}w{sp}pour{sp}{sp}t=1,{sp}z=0.5,{sp}M=10,{sp}m=1.5,{sp}\beta=10{sp}et{sp}\omega=50$', fontsize=16)
    
    # ax1
    plt.plot(r_s, df_occlusion_1.iloc[:, 943], linewidth=1, label=r'$\epsilon=0.1$', color='crimson')
    plt.plot(r_s, df_occlusion_15.iloc[:, 1231], linewidth=1, label=r'$\epsilon=0.15$')
    plt.plot(r_s, df_default.iloc[:, 1676], linewidth=1, label=r'$\epsilon=0.2$')

    plt.xlabel('r', fontsize=22)
    plt.ylabel('w', fontsize=22)
    plt.legend(framealpha=0.1)
    plt.tight_layout()
    
    plt.savefig('figs/newtonian-unsteady-occlusion-latest.png', transparent=True)

# %%
# @np.vectorize
def wr1(w_df, z=0.5, t=1):
    dr = (r2(z) - r1) / _N
    t_i = int(w_df.shape[1] * t)
    if t == 1:
        t_i -= 1
    return -3 * w_df.iloc[0, t_i] + 4 * w_df.iloc[1, t_i] - w_df.iloc[2, t_i] / (2 * dr)

# @np.vectorize
def wr2(w_df, z=0.5, t=1):
    dr = (r2(z) - r1) / _N
    nr = _N - 1
    t_i = int(w_df.shape[1] * t)
    if t == 1:
        t_i -= 1
    return -3 * w_df.iloc[nr, t_i] + 4 * w_df.iloc[nr-1, t_i] - w_df.iloc[nr-2, t_i] / (2 * dr)

# %%
zs = np.linspace(0, 1, 5)
ts = np.linspace(0, 1, 200)
dpdz_1 = np.zeros((5, 200))
for i in range(5):
    for j in range(200):
        w1 = wr1(df_default, z=zs[i], t=ts[j])
        w2 = wr2(df_default, z=zs[i], t=ts[j])
        dpdz_1[i, j] = dpdz(w2, w1, z=zs[i], t=ts[j])

# %%
with plt.style.context('fivethirtyeight'):
    frac = r'\frac{\partial P}{\partial z}'
    sp = r'\hspace{0.25}'
    t = fr'$Représentation{sp}graphique{sp}de{sp}{frac}{sp}en{sp}fonction{sp}de{sp}temps{sp}t{sp}pour{sp}M=10,{sp}m=1.5{sp}et{sp}\omega=10$'
    fig = plt.gcf()
    fig.set_size_inches(12.5, 5.5)
    plt.title(t, fontsize=13)
    
    plt.xlabel('t')
    plt.ylabel(f'${frac}$', fontsize=24)
    
    plt.tight_layout()
    
    plt.plot(ts, dpdz_1[0, :], linewidth=1, label=f'z={zs[0]}')
#     plt.plot(ts, dpdz_2[1, :], linewidth=1, label=f'z={zs[1]}')
    plt.plot(ts, dpdz_1[2, :], linewidth=1, label=f'z={zs[2]}')
    plt.plot(ts, dpdz_1[3, :], linewidth=1, label=f'z={zs[3]}')
    plt.legend(framealpha=0.1)
    
#     plt.savefig('newtonian-unsteady-pressure-gradient.png', transparent=True)

# %%
w1 = wr1(df_hartmann_1, z=zs[i], t=ts[j])
w2 = wr2(df_hartmann_1, z=zs[i], t=ts[j])
dpdz_2 = dpdz(w2, w1, t=ts, M=1)

# %%
w1 = wr1(df_hartmann_20, z=zs[i], t=ts[j])
w2 = wr2(df_hartmann_20, z=zs[i], t=ts[j])
dpdz_3 = dpdz(w2, w1, t=ts, M=20)

# %%
with plt.style.context('fivethirtyeight'):
    frac = r'\frac{\partial P}{\partial z}'
    sp = r'\hspace{0.25}'
#     t = fr'$Représentation{sp}graphique{sp}de{sp}{frac}{sp}en{sp}fonction{sp}de{sp}temps{sp}t{sp}pour{sp}M=10,{sp}m=1.5{sp}et{sp}\omega=10$'
    fig = plt.gcf()
    fig.set_size_inches(12.5, 5.5)
    plt.title(t, fontsize=13)
    
    plt.xlabel('t')
    plt.ylabel(f'${frac}$', fontsize=24)
    
    plt.tight_layout()
    
    plt.plot(ts, dpdz_2, linewidth=1, label='M=1')    
    plt.plot(ts, dpdz_1[4, :], linewidth=1, label='M=10')
    plt.plot(ts, dpdz_3, linewidth=1, label='M=20')
    
    plt.legend(framealpha=0.1)
    
    plt.savefig('newtonian-unsteady-pressure-gradient-hartmann.png', transparent=True)
