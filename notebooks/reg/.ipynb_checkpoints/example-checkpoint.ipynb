# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
import os
def path(img):
    base = '/mnt/c/Users/dell/desktop/pfe/regression'
    return os.path.join(base, img)

# %%
dataset_x = [3, 3.2, 3.6, 4]
dataset_y = [5.6, 6.1, 6.8, 7.2]
dataset = { 'x': dataset_x, 'y': dataset_y }
df = pd.DataFrame.from_dict(dataset)
df.index += 1
df
# Out:
#      x    y
# 1  3.0  5.6
# 2  3.2  6.1
# 3  3.6  6.8
# 4  4.0  7.2

# %%
with plt.style.context('fivethirtyeight'):
    plt.scatter(df.x, df.y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.tight_layout()
    plt.savefig(path('scatter.png'), transparent=True)
    plt.show()

# %%
def get_y(x, a, b):
    a *= 2
    b *= 2
    return a * x + b

x = np.linspace(3, 4, 100)
y = np.vectorize(get_y)

# %%
with plt.style.context('fivethirtyeight'):
    for _ in range(3):
        a, b = np.random.rand(2)
        plt.plot(x, y(x, a, b), label=f'a={a * 2:.2f} et b={b * 2:.2f}')
    plt.scatter(df.x, df.y, label='valeurs mesurées', color='green')
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.tight_layout()
    plt.savefig(path('lines2.png'), transparent=True)
    plt.show()

# %%
def estimate(x):
    a, b = 1.5, 1.2
    return a * x + b

x = np.linspace(3, 4, 100)
y = np.vectorize(estimate)
    
with plt.style.context('fivethirtyeight'):
    # plots
    plt.scatter(df.x, df.y, label='valeurs mesurées')
    plt.plot(x, y(x), color='green', linewidth=1)
    
    # texts
    plt.text(3.03, 5.66, 'erreur', color='red')
    plt.text(3, 5.66, '}', fontsize=12, color='red')
    
    plt.text(3.03, 6.02, 'erreur', color='red')
    plt.text(3.17, 6.02, '{', fontsize=12, color='red')
    
    plt.text(3.42, 6.65, 'erreur', color='red')
    plt.text(3.55, 6.65, '{', fontsize=23, color='red')
    
    plt.text(3.6, 6.5, 'y(x)=ax+b')
    
    # plot settings
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.tight_layout()
    plt.savefig(path('errors.png'), transparent=True)
    plt.show()

# %%
xb = df.x.sum() / len(df.x)
yb = df.y.sum() / len(df.y)
def a():
    num = df.x * (df.y - yb)
    denum = df.x * (df.x - xb)
    return num.sum() / denum.sum()

def b():
    return yb - xb * a()

# %%
slope = a()
intercept = b()

# %%
print(f'Slope: {slope}', f'Intercept: {intercept}', sep='\n')
# Out:
# Slope: 1.5847457627118684
# Intercept: 0.9576271186440533

# %%
reg = LinearRegression()
reg.fit(df[['x']], df.y)

def y_reg(x):
    a = reg.coef_[0]
    b = reg.intercept_
    return a * x + b

x = np.linspace(3, 4, 50)
y_reg = np.vectorize(y_reg)

# %%
with plt.style.context('fivethirtyeight'):
    plt.scatter(df.x, df.y, label='Valeur mesurée')
    plt.plot(x, y_reg(x), linewidth=1, color='red', label='Droite de regression')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.tight_layout()
    plt.savefig(path('regression_line.png'), transparent=True)

# %%
# algebric approach
y = df.y
ones = np.ones((4, ))
x = np.transpose(np.hstack((df.x, ones)).reshape(2, 4))
xt = np.transpose(x)
A = np.dot(xt, x)
Ai = np.linalg.inv(A)
xty = np.dot(xt, y)
M = np.dot(Ai, xty)
M
# Out:
# array([1.58474576, 0.95762712])

# %%
reg.intercept_
# Out:
# 0.9576271186440648
